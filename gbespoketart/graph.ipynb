# %%
import os

import seaborn as sns
import numpy as np

# %%
load_path = ("../gbespoketart/trained_model/2023-11-12:13-22-48")

# %%
metrics = {}
for file in os.listdir(load_path):
    if ".npy" not in file:
        continue 

    metrics[file[:file.index(".")]] = np.load(os.path.join(load_path,file))

# %%
for key in metrics:
    if "test" in key and "loss" not in key:
        ax = sns.lineplot(x=[i for i in range(1,1+len(metrics[key]))],
                     y=metrics[key], label=key)

# %%
for key in metrics:
    if "train" in key and "loss" not in key:
        ax = sns.lineplot(x=[i for i in range(1,1+len(metrics[key]))],
                          y=metrics[key], label=key)

# %%
sns.lineplot(x=[i for i in range(len(metrics["train_avg_loss"]))],
             y=metrics["train_avg_loss"], label="train_loss")
sns.lineplot(x=[i for i in range(len(metrics["test_avg_loss"]))],
             y=metrics["test_avg_loss"], label="test_loss")
# Out:
# <Axes: >

# %%
metrics
# Out:
# {'test_avg_loss': array([3.79125689, 4.61646085, 5.59764001, 6.58095364, 7.29605295,
#         7.88544876, 8.60283179]),
#  'test_eot_f1': array([0.        , 0.12222222, 0.19444446, 0.16666667, 0.08333334,
#         0.        , 0.11111111]),
#  'train_eot_f1': array([0.20666666, 0.24666667, 0.25      , 0.58333337, 0.51333332,
#         0.51666671, 0.5333333 ]),
#  'train_avg_loss': array([3.42092837, 2.2288337 , 1.38950622, 0.85909882, 0.56255104,
#         0.38927783, 0.2767961 ]),
#  'test_eot_acc': array([0.66666663, 0.6388889 , 0.66666669, 0.80555558, 0.77777773,
#         0.69444448, 0.72222227]),
#  'test_rouge_mean': array([0.02562442, 0.01825784, 0.02148062, 0.03134461, 0.02376898,
#         0.03221407, 0.02684962]),
#  'train_rouge_mean': array([0.03685076, 0.03903681, 0.04820406, 0.09494273, 0.199334  ,
#         0.24846206, 0.44477018]),
#  'train_eot_recall': array([0.2       , 0.30000001, 0.25      , 0.55000001, 0.60000002,
#         0.60000002, 0.60000002]),
#  'train_eot_acc': array([0.83333337, 0.83333337, 0.79999995, 0.9000001 , 0.86666667,
#         0.89999998, 0.85000002]),
#  'test_eot_recall': array([0.        , 0.11111111, 0.22222222, 0.16666667, 0.08333334,
#         0.        , 0.16666667])}
