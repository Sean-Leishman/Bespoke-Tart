# %%
import pandas as pd
import os

# %%
pd.read_csv("linguistic_background.csv")
# Out:
#     CONVERSATION_ID PARTICIPANT_ID DATASET_VERSION RECORDING_TIME  \
# 0         EDACC-C01    EDACC-C01-A            V1.0        0:18:06
# 1         EDACC-C01    EDACC-C01-B            V1.0        0:18:06
# 2         EDACC-C02    EDACC-C02-A            V1.0        0:16:38
# 3         EDACC-C02    EDACC-C02-B            V1.0        0:16:38
# 4         EDACC-C03    EDACC-C03-A            V1.0        0:14:43
# ..              ...            ...             ...            ...
# 117       EDACC-C63    EDACC-C63-B            V1.0       00:32:10
# 118       EDACC-C64    EDACC-C64-A            V1.0        0:32:06
# 119       EDACC-C64    EDACC-C64-B            V1.0        0:32:06
# 120       EDACC-C67    EDACC-C67-A            V1.0        0:22:39
# 121       EDACC-C67    EDACC-C67-B            V1.0        0:22:39
#
#         Timestamp_Survey What is your gender?  \
# 0    03/05/2022 10:13:45                 Male
# 1    06/05/2022 19:35:41               Female
# ...

# %%
lines = []
with open("data/dev/text") as f:
    lines = f.readlines()

# %%
line = lines[0]

# %%
conv_id = line[:9]
text = line[20:]
text.strip()
# Out:
# 'c eleven dash p one'

# %%
line[10:19]
# Out:
# '000000000'

# %%
print(len(lines))
# Out:
# 9848
